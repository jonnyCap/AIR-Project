# %%
import torch
from torch.utils.data import Dataset, DataLoader, Subset
import pandas as pd
from sentence_transformers import SentenceTransformer
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import warnings
# Suppress FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning)
import sys
sys.path.append('/kaggle/input/retrievalmodel/pytorch/default/1')

import spacy

import datasets
datasets.disable_progress_bar()

import logging
logging.getLogger("spacy").setLevel(logging.ERROR)
logging.getLogger("sentence_transformers").setLevel(logging.ERROR)

from tqdm import tqdm
import joblib

# Dataset class to load and preprocess CSV data
class BusinessIdeaDataset(Dataset):
    def __init__(self, csv_file, max_length=512):
        self.csv_file = csv_file
        self.data = pd.read_csv(csv_file)
        self.max_length = max_length
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # Normalize the stock performance columns
        self.data['Historical'] = self.data['Historical'].apply(lambda x: eval(x) if isinstance(x, str) else x)
        historical_prices = self.data['Historical'].apply(pd.Series)
        scaler = MinMaxScaler()
        normalized_prices = scaler.fit_transform(historical_prices)
        joblib.dump(scaler, 'stock_scaler.pkl')
        self.data['Normalized_Historical'] = normalized_prices.tolist()
        
        score_scaler = MinMaxScaler()
        self.data['Normalized_Score'] = score_scaler.fit_transform(self.data[['Score_2']])
        joblib.dump(score_scaler, 'score_scaler.pkl')
        
        import seaborn as sns
        import matplotlib.pyplot as plt
        
        sns.histplot(self.data['Normalized_Score'], kde=True)
        plt.title("Distribution of Normalized Scores")
        plt.show()

        self.model_type = 'all-MiniLM-L6-v2'
        self.model = SentenceTransformer(self.model_type)
        self.model = self.model.to(self.device)
        self.nlp = spacy.load("en_core_web_sm")
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        idea = row['Idea']
        score_2 = torch.tensor(row['Normalized_Score'], dtype=torch.float).to(self.device)  # use score 2 because it has the best distribution in the given dataset
        stock_performance = torch.tensor(row['Normalized_Historical'], dtype=torch.float).to(self.device)
        
        # Tokenizing the idea text
        bert_encodings = self.encode(idea)
        bert_encodings = torch.tensor(bert_encodings, dtype=torch.float).to(self.device)

        if torch.any(torch.isnan(bert_encodings)) or torch.any(torch.isnan(stock_performance)):
            print(f"NaN detected in data at index {idx}")
            return None  # Return None if the data is invalid
        
        return {
            'idea_encoding': bert_encodings,
            'stock_performance': stock_performance,
            'score': score_2
        }

    def encode(self, text: str):
        doc = self.nlp(text)
        # Remove stop words and punctuation, and apply lemmatization
        preprocessed_text = " ".join(
            [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
        )
        return self.model.encode(preprocessed_text)

# Ranking model to predict the score based on encoded idea and stock data
class EnhancedRankingModel(nn.Module):
    def __init__(self, encoding_dim=384, historical_dim=12, hidden_size=128, dropout_rate=0.1):
        """
        A neural network model for ranking business ideas based on textual encoding and historical stock data.
        """
        super(EnhancedRankingModel, self).__init__()

        # Idea encoding branch
        self.idea_fc = nn.Sequential(
            nn.Linear(encoding_dim, hidden_size),
            nn.LayerNorm(hidden_size),  # Batch normalization
            nn.ReLU(),
            nn.Dropout(dropout_rate)
        )
        
        # Historical stock data branch
        self.stock_fc = nn.Sequential(
            nn.Linear(historical_dim, hidden_size //2),
            nn.LayerNorm(hidden_size //2),  # Batch normalization
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_size // 2, hidden_size),
            nn.ReLU(),
        )
        
        self.attention = nn.MultiheadAttention(embed_dim= hidden_size, num_heads=2, batch_first=True)
        
        # Combined branch
        self.combined_fc = nn.Sequential(
            nn.Linear(2 * hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_size, hidden_size//2),
            nn.ReLU(),
            nn.Linear(hidden_size//2, 1)
        )
        
    
    def forward(self, idea_encoding, stock_performance):
        """
        Forward pass through the model.
        """
        # Process idea encoding
        idea_features = self.idea_fc(idea_encoding)
        
        # Process historical stock performance
        stock_features = self.stock_fc(stock_performance)
        
        # Concatenate the features
        combined_features = torch.stack((idea_features, stock_features), dim=1) # Shape: [batch, 2, hidden_size]
        #print(idea_features.shape)
        #print(stock_features.shape)
        #print(combined_features.shape)
        attention_output, _ = self.attention(combined_features, combined_features, combined_features) # Shape: [batch, 2, hidden_size]
    
        # Remove the sequence dimension added by attention (squeeze dim=1)
        flattened_features = attention_output.reshape(attention_output.size(0), -1)  # Shape: [batch, 2 * hidden_size]

        # Compute the score
        score = self.combined_fc(flattened_features).squeeze()
        
        return score


# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load the dataset
dataset = BusinessIdeaDataset(
    csv_file="/kaggle/input/paddedentirefinaldataset/padded_entire_final_dataset.csv"
)

# Split indices into training (80%) and evaluation (20%)
train_indices, val_indices = train_test_split(
    list(range(len(dataset))), test_size=0.2, random_state=42  # For reproducibility
)

# Create subsets for training and validation
train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)

# Create data loaders for training and validation
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# Move the model to GPU
model = EnhancedRankingModel().to(device)

# Optimizer and loss function remain the same
from torch.optim.lr_scheduler import ReduceLROnPlateau

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5)

loss_fn = nn.MSELoss()

import numpy as np
def evaluate_model(model, val_loader, device, amount_scores = 150):
    model.eval()
    
    # Store predicted and actual values
    predicted_scores = []
    actual_scores = []
    
    with torch.no_grad():
        for batch in val_loader:
            idea_encoding = batch['idea_encoding'].to(device)
            stock_performance = batch['stock_performance'].to(device)
            scores = batch['score'].to(device)

            pred_scores = model(idea_encoding, stock_performance)
            predicted_scores.extend(pred_scores.cpu().numpy())
            actual_scores.extend(scores.cpu().numpy())

            if len(predicted_scores) >= amount_scores:
                break
    
    plt.figure(figsize=(8, 6))
    plt.scatter(actual_scores, predicted_scores, color='blue', label='Predicted vs Actual')
    
    plt.plot([min(actual_scores), max(actual_scores)], [min(actual_scores), max(actual_scores)], color='red', linestyle='--', label='Perfect Prediction Line')
    
    plt.xlabel('Actual Scores')
    plt.ylabel('Predicted Scores')
    #plt.title(f'Predicted vs Actual Scores (Sample of {amount_scores} Examples)')
    plt.title(f'Predicted vs Actual Scores')
    plt.legend()
    plt.grid(True)
    plt.show()

    return predicted_scores, actual_scores

# Training loop
epochs = 50
print('Start Training...')
training_losses = []
validation_losses = []
best_val_loss = float('inf')
patience = 5
epochs_without_improvement = 0

for epoch in range(epochs):
    if epoch != 0 and epoch % 4 == 0:
        plt.figure(figsize=(10, 6))
        plt.plot(range(1, len(training_losses) + 1), training_losses, label="Training Loss", marker='o')
        plt.plot(range(1, len(validation_losses) + 1), validation_losses, label="Validation Loss", marker='o')
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title(f"Training and Validation Loss up to Epoch {epoch + 1}")
        plt.legend()
        plt.show()
        evaluate_model(model, val_loader, device)
        torch.save(model.state_dict(), "ranking_model_weights.pth")
        print("Model weights saved successfully!")

    # Training phase
    model.train()
    train_loss = 0.0
    for batch in tqdm(train_loader, desc="Training Progress"):
        idea_encoding = batch['idea_encoding'].to(device)
        stock_performance = batch['stock_performance'].to(device)
        scores = batch['score'].to(device)
        optimizer.zero_grad()
        predicted_scores = model(idea_encoding, stock_performance)
        loss = loss_fn(predicted_scores, scores)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    # Validation phase
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Validation Progress"):
            idea_encoding = batch['idea_encoding'].to(device)
            stock_performance = batch['stock_performance'].to(device)
            scores = batch['score'].to(device)

            predicted_scores = model(idea_encoding, stock_performance)
            loss = loss_fn(predicted_scores, scores)
            val_loss += loss.item()
    
    avg_train_loss = train_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)

    training_losses.append(avg_train_loss)
    validation_losses.append(avg_val_loss)
    
    print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}")

    # Early stopping logic
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1

    if epochs_without_improvement >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break

# Save the final model weights
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(training_losses) + 1), training_losses, label="Training Loss", marker='o')
plt.plot(range(1, len(validation_losses) + 1), validation_losses, label="Validation Loss", marker='o')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"Training and Validation Loss up to Epoch {epoch + 1}")
plt.legend()
plt.show()
evaluate_model(model, val_loader, device)
torch.save(model.state_dict(), "ranking_model_weights.pth")
print("Model weights saved successfully!")
# Out:
# Using device: cuda
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# Start Training...
# Training Progress: 100%|██████████| 323/323 [02:44<00:00,  1.96it/s]
# Validation Progress: 100%|██████████| 81/81 [00:39<00:00,  2.06it/s]
# Epoch 1/50, Training Loss: 0.0463, Validation Loss: 0.0437
# Training Progress: 100%|██████████| 323/323 [02:36<00:00,  2.06it/s]
# Validation Progress: 100%|██████████| 81/81 [00:38<00:00,  2.10it/s]
# Epoch 2/50, Training Loss: 0.0413, Validation Loss: 0.0430
# Training Progress: 100%|██████████| 323/323 [02:36<00:00,  2.06it/s]
# Validation Progress: 100%|██████████| 81/81 [00:38<00:00,  2.08it/s]
# Epoch 3/50, Training Loss: 0.0399, Validation Loss: 0.0432
# Training Progress: 100%|██████████| 323/323 [02:34<00:00,  2.09it/s]
# Validation Progress: 100%|██████████| 81/81 [00:38<00:00,  2.08it/s]
# Epoch 4/50, Training Loss: 0.0378, Validation Loss: 0.0433
# Model weights saved successfully!
# Training Progress: 100%|██████████| 323/323 [02:36<00:00,  2.06it/s]
# Validation Progress: 100%|██████████| 81/81 [00:38<00:00,  2.08it/s]
# Epoch 5/50, Training Loss: 0.0351, Validation Loss: 0.0441
# Training Progress: 100%|██████████| 323/323 [02:37<00:00,  2.06it/s]
# Validation Progress: 100%|██████████| 81/81 [00:39<00:00,  2.07it/s]
# Epoch 6/50, Training Loss: 0.0322, Validation Loss: 0.0429
# Training Progress: 100%|██████████| 323/323 [02:36<00:00,  2.06it/s]
# Validation Progress: 100%|██████████| 81/81 [00:38<00:00,  2.08it/s]
# Epoch 7/50, Training Loss: 0.0293, Validation Loss: 0.0434
# Training Progress: 100%|██████████| 323/323 [02:36<00:00,  2.06it/s]
# Validation Progress: 100%|██████████| 81/81 [00:39<00:00,  2.04it/s]
# Epoch 8/50, Training Loss: 0.0257, Validation Loss: 0.0461
# Model weights saved successfully!
# Training Progress: 100%|██████████| 323/323 [02:39<00:00,  2.03it/s]
# Validation Progress: 100%|██████████| 81/81 [00:39<00:00,  2.05it/s]
# Epoch 9/50, Training Loss: 0.0221, Validation Loss: 0.0459
# Training Progress: 100%|██████████| 323/323 [02:35<00:00,  2.08it/s]
# Validation Progress: 100%|██████████| 81/81 [00:38<00:00,  2.13it/s]
# Epoch 10/50, Training Loss: 0.0189, Validation Loss: 0.0473
# Training Progress: 100%|██████████| 323/323 [02:35<00:00,  2.07it/s]
# Validation Progress: 100%|██████████| 81/81 [00:38<00:00,  2.08it/s]
# Epoch 11/50, Training Loss: 0.0168, Validation Loss: 0.0482
# Early stopping triggered after 11 epochs.
# Model weights saved successfully!

# %%
predicted_scores, actual_scores = evaluate_model(model, val_loader, device)
print(f"Predicted vs Actual Scores ({len(predicted_scores)} Examples):")
print("=========================================")
for i, (actual, predicted) in enumerate(zip(actual_scores, predicted_scores), 1):
    print(f"Example {i}: Actual = {actual:.4f}, Predicted = {predicted:.4f}")
# Out:
# Predicted vs Actual Scores (160 Examples):
# =========================================
# Example 1: Actual = 0.0106, Predicted = 0.2709
# Example 2: Actual = 0.0659, Predicted = 0.0903
# Example 3: Actual = 0.4053, Predicted = 0.2493
# Example 4: Actual = 0.3272, Predicted = 0.4498
# Example 5: Actual = 0.1649, Predicted = 0.4484
# Example 6: Actual = 0.2830, Predicted = 0.3443
# Example 7: Actual = 0.4728, Predicted = 0.4395
# Example 8: Actual = 0.2883, Predicted = 0.3821
# Example 9: Actual = 0.4497, Predicted = 0.3256
# Example 10: Actual = 0.5924, Predicted = 0.3407
# Example 11: Actual = 0.2905, Predicted = 0.3203
# Example 12: Actual = 0.4196, Predicted = 0.0968
# Example 13: Actual = 0.3897, Predicted = 0.3401
# Example 14: Actual = 0.3167, Predicted = 0.4325
# Example 15: Actual = 0.3303, Predicted = 0.3323
# Example 16: Actual = 0.6722, Predicted = 0.4814
# Example 17: Actual = 0.2827, Predicted = 0.2906
# Example 18: Actual = 0.5940, Predicted = 0.4907
# Example 19: Actual = 0.3248, Predicted = 0.3482
# Example 20: Actual = 0.3213, Predicted = 0.3673
# Example 21: Actual = 0.2902, Predicted = 0.4001
# Example 22: Actual = 0.5019, Predicted = 0.4296
# Example 23: Actual = 0.4312, Predicted = 0.6789
# Example 24: Actual = 0.3168, Predicted = 0.3356
# Example 25: Actual = 0.0756, Predicted = 0.2735
# Example 26: Actual = 0.1883, Predicted = 0.3776
# Example 27: Actual = 0.3755, Predicted = 0.3137
# Example 28: Actual = 0.3475, Predicted = 0.4088
# Example 29: Actual = 0.2394, Predicted = 0.4170
# Example 30: Actual = 0.5391, Predicted = 0.3071
# Example 31: Actual = 0.8055, Predicted = 0.1725
# Example 32: Actual = 0.2424, Predicted = 0.3525
# Example 33: Actual = 0.1796, Predicted = 0.0819
# Example 34: Actual = 0.3769, Predicted = 0.3357
# Example 35: Actual = 0.5009, Predicted = 0.4538
# Example 36: Actual = 0.5458, Predicted = 0.6073
# Example 37: Actual = 0.2671, Predicted = 0.3460
# Example 38: Actual = 0.0000, Predicted = 0.0270
# Example 39: Actual = 0.8824, Predicted = 0.4194
# Example 40: Actual = 0.4509, Predicted = 0.4093
# Example 41: Actual = 0.4929, Predicted = 0.5464
# Example 42: Actual = 0.5794, Predicted = 0.4789
# Example 43: Actual = 0.0824, Predicted = 0.1395
# Example 44: Actual = 0.3879, Predicted = 0.4690
# Example 45: Actual = 0.3313, Predicted = 0.2928
# Example 46: Actual = 0.4646, Predicted = 0.4960
# Example 47: Actual = 0.0608, Predicted = 0.2907
# Example 48: Actual = 0.0000, Predicted = 0.2853
# Example 49: Actual = 0.1507, Predicted = 0.3033
# Example 50: Actual = 0.4661, Predicted = 0.4771
# Example 51: Actual = 0.0000, Predicted = 0.1394
# Example 52: Actual = 0.4473, Predicted = 0.3455
# Example 53: Actual = 0.7338, Predicted = 0.3732
# Example 54: Actual = 0.3449, Predicted = 0.1951
# Example 55: Actual = 0.7697, Predicted = 0.2536
# Example 56: Actual = 0.0457, Predicted = 0.0292
# Example 57: Actual = 0.1007, Predicted = 0.2246
# Example 58: Actual = 0.0851, Predicted = 0.1548
# Example 59: Actual = 0.4425, Predicted = 0.1201
# Example 60: Actual = 0.1192, Predicted = 0.1746
# Example 61: Actual = 0.2336, Predicted = 0.2120
# Example 62: Actual = 0.8312, Predicted = 0.4015
# Example 63: Actual = 0.0000, Predicted = 0.1277
# Example 64: Actual = 0.0000, Predicted = 0.2822
# Example 65: Actual = 0.5751, Predicted = 0.3023
# Example 66: Actual = 0.7333, Predicted = 0.5299
# Example 67: Actual = 0.3322, Predicted = 0.3606
# Example 68: Actual = 0.4156, Predicted = 0.3455
# Example 69: Actual = 0.5943, Predicted = 0.0228
# Example 70: Actual = 0.0000, Predicted = 0.2510
# Example 71: Actual = 0.2137, Predicted = 0.4478
# Example 72: Actual = 0.2834, Predicted = 0.3170
# Example 73: Actual = 0.3662, Predicted = 0.4460
# Example 74: Actual = 0.3560, Predicted = 0.3040
# Example 75: Actual = 0.6315, Predicted = 0.5614
# Example 76: Actual = 0.2748, Predicted = 0.3643
# Example 77: Actual = 0.2524, Predicted = 0.3119
# Example 78: Actual = 0.5360, Predicted = 0.3850
# Example 79: Actual = 0.1205, Predicted = 0.1833
# Example 80: Actual = 0.1592, Predicted = 0.3634
# Example 81: Actual = 0.0257, Predicted = 0.2316
# Example 82: Actual = 0.5521, Predicted = 0.3256
# Example 83: Actual = 0.2379, Predicted = 0.7250
# Example 84: Actual = 0.0000, Predicted = 0.2235
# Example 85: Actual = 0.2811, Predicted = 0.3890
# Example 86: Actual = 0.0557, Predicted = 0.0429
# Example 87: Actual = 0.3232, Predicted = 0.3786
# Example 88: Actual = 0.2146, Predicted = 0.1332
# Example 89: Actual = 0.4211, Predicted = 0.1580
# Example 90: Actual = 0.0495, Predicted = 0.4550
# Example 91: Actual = 0.1338, Predicted = 0.5210
# Example 92: Actual = 0.0000, Predicted = 0.0687
# Example 93: Actual = 0.2713, Predicted = 0.1151
# Example 94: Actual = 0.2326, Predicted = 0.3608
# Example 95: Actual = 0.0000, Predicted = 0.0989
# Example 96: Actual = 0.3498, Predicted = 0.2923
# Example 97: Actual = 0.1795, Predicted = 0.2873
# Example 98: Actual = 0.3317, Predicted = 0.5998
# Example 99: Actual = 0.0000, Predicted = 0.2606
# Example 100: Actual = 0.7192, Predicted = 0.3214
# Example 101: Actual = 0.3390, Predicted = 0.3196
# Example 102: Actual = 0.2860, Predicted = 0.3172
# Example 103: Actual = 0.2598, Predicted = 0.2958
# Example 104: Actual = 0.8161, Predicted = 0.3626
# Example 105: Actual = 0.7324, Predicted = 0.5444
# Example 106: Actual = 0.3507, Predicted = 0.4821
# Example 107: Actual = 0.6670, Predicted = 0.1102
# Example 108: Actual = 0.0689, Predicted = 0.1010
# Example 109: Actual = 0.2862, Predicted = 0.3390
# Example 110: Actual = 0.3039, Predicted = 0.2918
# Example 111: Actual = 0.1268, Predicted = 0.1456
# Example 112: Actual = 0.4686, Predicted = 0.4439
# Example 113: Actual = 0.2972, Predicted = 0.3272
# Example 114: Actual = 0.6094, Predicted = 0.3449
# Example 115: Actual = 0.2888, Predicted = 0.3412
# Example 116: Actual = 0.2802, Predicted = 0.4501
# Example 117: Actual = 0.5794, Predicted = 0.4700
# Example 118: Actual = 0.3895, Predicted = 0.5259
# Example 119: Actual = 0.1788, Predicted = 0.1449
# Example 120: Actual = 0.6066, Predicted = 0.5911
# Example 121: Actual = 0.2650, Predicted = 0.2941
# Example 122: Actual = 0.2676, Predicted = 0.5023
# Example 123: Actual = 0.2559, Predicted = 0.3942
# Example 124: Actual = 0.0000, Predicted = 0.0823
# Example 125: Actual = 0.5508, Predicted = 0.5440
# Example 126: Actual = 0.4503, Predicted = 0.4551
# Example 127: Actual = 0.5156, Predicted = 0.3336
# Example 128: Actual = 0.0759, Predicted = 0.3922
# Example 129: Actual = 0.5404, Predicted = 0.3947
# Example 130: Actual = 0.4139, Predicted = 0.3776
# Example 131: Actual = 0.0454, Predicted = 0.2666
# Example 132: Actual = 0.8941, Predicted = 0.1081
# Example 133: Actual = 0.2171, Predicted = 0.3861
# Example 134: Actual = 0.3818, Predicted = 0.3485
# Example 135: Actual = 0.0000, Predicted = 0.2958
# Example 136: Actual = 0.0197, Predicted = 0.3474
# Example 137: Actual = 0.2896, Predicted = 0.3638
# Example 138: Actual = 0.2995, Predicted = 0.0945
# Example 139: Actual = 0.3943, Predicted = 0.5113
# Example 140: Actual = 0.0000, Predicted = 0.2880
# Example 141: Actual = 0.0333, Predicted = 0.1821
# Example 142: Actual = 0.3264, Predicted = 0.3166
# Example 143: Actual = 0.1307, Predicted = 0.0232
# Example 144: Actual = 0.4146, Predicted = 0.6154
# Example 145: Actual = 0.6208, Predicted = 0.3905
# Example 146: Actual = 0.0000, Predicted = 0.1095
# Example 147: Actual = 0.2273, Predicted = 0.4485
# Example 148: Actual = 0.2586, Predicted = 0.3381
# Example 149: Actual = 0.0000, Predicted = 0.4850
# Example 150: Actual = 0.3728, Predicted = 0.3147
# Example 151: Actual = 0.2754, Predicted = 0.3994
# Example 152: Actual = 0.3410, Predicted = 0.3455
# Example 153: Actual = 0.0000, Predicted = 0.4865
# Example 154: Actual = 0.6157, Predicted = 0.5356
# Example 155: Actual = 0.0000, Predicted = 0.2357
# Example 156: Actual = 0.7785, Predicted = 0.2947
# Example 157: Actual = 0.4451, Predicted = 0.2911
# Example 158: Actual = 0.2855, Predicted = 0.3590
# Example 159: Actual = 0.6738, Predicted = 0.5126
# Example 160: Actual = 0.1315, Predicted = 0.1742
